# %% [markdown]
# <a href="https://colab.research.google.com/github/RitwikRaj29/KMSWT_PROJECT/blob/main/KMSWT_commented.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wikipedia-api neptune pandas spacy networkx scipy #installing the dependencies
# !pip install SPARQLWrapper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wikipedia-api
#   Downloading Wikipedia_API-0.5.8-py3-none-any.whl (13 kB)
# Collecting neptune
#   Downloading neptune-1.1.1-py3-none-any.whl (442 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.6/442.6 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (1.5.3)
# Requirement already satisfied: spacy in /usr/local/lib/python3.9/dist-packages (3.5.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (3.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (1.10.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from wikipedia-api) (2.27.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from neptune) (5.9.4)
# Requirement already satisfied: websocket-client!=1.0.0,>=0.35.0 in /usr/local/lib/python3.9/dist-packages (from neptune) (1.5.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from neptune) (1.26.15)
# Collecting GitPython>=2.0.8
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 18.8 MB/s eta 0:00:00
# Collecting boto3>=1.16.0
#   Downloading boto3-1.26.114-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 14.7 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/dist-packages (from neptune) (1.16.0)
# Requirement already satisfied: oauthlib>=2.1.0 in /usr/local/lib/python3.9/dist-packages (from neptune) (3.2.2)
# Requirement already satisfied: Pillow>=1.1.6 in /usr/local/lib/python3.9/dist-packages (from neptune) (8.4.0)
# Requirement already satisfied: future>=0.17.1 in /usr/local/lib/python3.9/dist-packages (from neptune) (0.18.3)
# Collecting swagger-spec-validator>=2.7.4
#   Downloading swagger_spec_validator-3.0.3-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from neptune) (23.0)
# Collecting bravado<12.0.0,>=11.0.0
#   Downloading bravado-11.0.3-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: requests-oauthlib>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from neptune) (1.3.1)
# Collecting PyJWT
#   Downloading PyJWT-2.6.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.9/dist-packages (from neptune) (8.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.9/dist-packages (from pandas) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from spacy) (67.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.9/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.1.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.9/dist-packages (from spacy) (8.1.9)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.10.7)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.9/dist-packages (from spacy) (6.3.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.9/dist-packages (from spacy) (2.4.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (4.65.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.9/dist-packages (from spacy) (2.0.8)
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting botocore<1.30.0,>=1.29.114
#   Downloading botocore-1.29.114-py3-none-any.whl (10.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 61.6 MB/s eta 0:00:00
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from bravado<12.0.0,>=11.0.0->neptune) (4.5.0)
# Collecting monotonic
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting simplejson
#   Downloading simplejson-3.19.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.4/137.4 kB 17.3 MB/s eta 0:00:00
# Requirement already satisfied: msgpack in /usr/local/lib/python3.9/dist-packages (from bravado<12.0.0,>=11.0.0->neptune) (1.0.5)
# Collecting bravado-core>=5.16.1
#   Downloading bravado_core-5.17.1-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from bravado<12.0.0,>=11.0.0->neptune) (6.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->wikipedia-api) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->wikipedia-api) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->wikipedia-api) (3.4)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.9/dist-packages (from swagger-spec-validator>=2.7.4->neptune) (4.3.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->spacy) (2.1.2)
# Collecting jsonref
#   Downloading jsonref-1.1.0-py3-none-any.whl (9.4 kB)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune) (0.19.3)
# Collecting jsonpointer>1.13
#   Downloading jsonpointer-2.3-py2.py3-none-any.whl (7.8 kB)
# Collecting rfc3339-validator
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting rfc3987
#   Downloading rfc3987-1.3.8-py2.py3-none-any.whl (13 kB)
# Collecting isoduration
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting fqdn
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: webcolors>=1.11 in /usr/local/lib/python3.9/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune) (1.13)
# Collecting uri-template
#   Downloading uri_template-1.2.0-py3-none-any.whl (10 kB)
# Collecting arrow>=0.15.0
#   Downloading arrow-1.2.3-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 5.1 MB/s eta 0:00:00
# Installing collected packages: rfc3987, monotonic, uri-template, smmap, simplejson, rfc3339-validator, PyJWT, jsonref, jsonpointer, jmespath, fqdn, wikipedia-api, swagger-spec-validator, gitdb, botocore, arrow, s3transfer, isoduration, GitPython, boto3, bravado-core, bravado, neptune
# Successfully installed GitPython-3.1.31 PyJWT-2.6.0 arrow-1.2.3 boto3-1.26.114 botocore-1.29.114 bravado-11.0.3 bravado-core-5.17.1 fqdn-1.5.1 gitdb-4.0.10 isoduration-20.11.0 jmespath-1.0.1 jsonpointer-2.3 jsonref-1.1.0 monotonic-1.6 neptune-1.1.1 rfc3339-validator-0.1.4 rfc3987-1.3.8 s3transfer-0.6.0 simplejson-3.19.1 smmap-5.0.0 swagger-spec-validator-3.0.3 uri-template-1.2.0 wikipedia-api-0.5.8
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting SPARQLWrapper
#   Downloading SPARQLWrapper-2.0.0-py3-none-any.whl (28 kB)
# Collecting rdflib>=6.1.1
#   Downloading rdflib-6.3.2-py3-none-any.whl (528 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 528.1/528.1 kB 19.9 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.9/dist-packages (from rdflib>=6.1.1->SPARQLWrapper) (3.0.9)
# Collecting isodate<0.7.0,>=0.6.0
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from isodate<0.7.0,>=0.6.0->rdflib>=6.1.1->SPARQLWrapper) (1.16.0)
# Installing collected packages: isodate, rdflib, SPARQLWrapper
# Successfully installed SPARQLWrapper-2.0.0 isodate-0.6.1 rdflib-6.3.2

# %%
import wikipediaapi  # pip install wikipedia-api
import pandas as pd
import concurrent.futures
from tqdm import tqdm
import requests
import csv
from bs4 import BeautifulSoup
import spacy
import pandas as pd
import requests
from spacy import displacy
# import en_core_web_sm
nlp = spacy.load('en_core_web_sm')
 
from spacy.tokens import Span
from spacy.matcher import Matcher
 
import matplotlib.pyplot as plot
from tqdm import tqdm
import networkx as nx
from matplotlib import pyplot as plt
from SPARQLWrapper import SPARQLWrapper, JSON

# %%
# !python -m spacy download en
# Out:
# 2023-04-17 19:19:00.756236: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ⚠ As of spaCy v3.0, shortcuts like 'en' are deprecated. Please use the
# full pipeline package name 'en_core_web_sm' instead.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 68.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.9/dist-packages (from en-core-web-sm==3.5.0) (3.5.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.9)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.22.4)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.10.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.65.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (23.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.27.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.4.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.7)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (6.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (67.6.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.5.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.4)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.9/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# URL of the Wikipedia page to scrape,we have taken the AI page as refernce
url = 'https://en.wikipedia.org/wiki/Artificial_intelligence'

# Send a GET request to the URL and get the response
response = requests.get(url)

# Create a BeautifulSoup object with the HTML content of the response
soup = BeautifulSoup(response.content, 'html.parser')

# Find all the paragraphs in the page content
paragraphs = soup.find_all('p')

# Create a CSV file to write the sentences into
with open('sentences.csv', mode='w') as csv_file:
    writer = csv.writer(csv_file)
    
    # Loop through each paragraph and split it into sentences
    for paragraph in paragraphs:
        sentences = paragraph.text.split('.')
        
        # Write each sentence into the CSV file
        for sentence in sentences:
            writer.writerow([sentence])

# %%
candidate_sentences = pd.read_csv("/content/sentences.csv")
candidate_sentences.shape
# Out:
# (495, 1)

# %%
candidate_sentences
# Out:
#                                                     \n
# 0    Artificial intelligence (AI) is intelligence d...
# 1     Example tasks in which this is done include s...
# 2                                                   \n
# 3    AI applications include advanced web search en...
# 4                                                    g
# ..                                                 ...
# 490  These were the four the most widely used AI te...
# 491                                     Later editions
# 492                                                 \n
# 493         The two most widely used textbooks in 2021
# 494  Open Syllabus: Explorer Archived 7 October 202...
#
# [495 rows x 1 columns]

# %%
candidate_sentences.set_axis(['sentence'], axis='columns', inplace=True)
# Out:
# <ipython-input-7-ebf8c0a10396>:1: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   candidate_sentences.set_axis(['sentence'], axis='columns', inplace=True)

# %%
candidate_sentences.head()
# Out:
#                                             sentence
# 0  Artificial intelligence (AI) is intelligence d...
# 1   Example tasks in which this is done include s...
# 2                                                 \n
# 3  AI applications include advanced web search en...
# 4                                                  g

# %%
candidate_sentences['sentence'] = candidate_sentences['sentence'].astype('string') #convert the column's datatype to string
candidate_sentences = candidate_sentences[candidate_sentences['sentence'].notna()] # drop the rows which have null values

# %%
def get_entities(sents):
   # chunk one
   enti_one = ""
   enti_two = ""
  
   dep_prev_token = "" # dependency tag of previous token in sentence
  
   txt_prev_token = "" # previous token in sentence
  
   prefix = ""
   modifier = ""
  
  
  
   for tokn in nlp(sents):
       # chunk two
       ## move to next token if token is punctuation
      
       if tokn.dep_ != "punct":
           #  check if token is compound word or not
           if tokn.dep_ == "compound":
               prefix = tokn.text
               # add the current word to it if the previous word is 'compound’
               if dep_prev_token == "compound":
                   prefix = txt_prev_token + " "+ tokn.text
                  
           # verify if token is modifier or not
           if tokn.dep_.endswith("mod") == True:
               modifier = tokn.text
               # add it to the current word if the previous word is 'compound'
               if dep_prev_token == "compound":
                   modifier = txt_prev_token + " "+ tokn.text
                  
           # chunk3
           if tokn.dep_.find("subj") == True:
               enti_one = modifier +" "+ prefix + " "+ tokn.text
               prefix = ""
               modifier = ""
               dep_prev_token = ""
               txt_prev_token = ""
              
           # chunk4
           if tokn.dep_.find("obj") == True:
               enti_two = modifier +" "+ prefix +" "+ tokn.text
              
           # chunk 5
           # update variable
           dep_prev_token = tokn.dep_
           txt_prev_token = tokn.text
          
   return [enti_one.strip(), enti_two.strip()]

# %%
#creation of the (subject,object) pair
entity_pairs = [] 

for i in tqdm(candidate_sentences["sentence"]):
    entity_pairs.append(get_entities(i))
# Out:
# 100%|██████████| 493/493 [00:04<00:00, 101.83it/s]

# %%
entity_pairs[10:20]
# Out:
# [['optical character recognition', 'frequently  things'],
#  ['', ''],
#  ['academic  it', 'new AI approaches'],
#  ['AI research', 'large problem knowledge'],
#  ['mathematical machine technique', 'challenging  industry'],
#  ['', ''],
#  ['fields', 'particular AI tools'],
#  ['traditional  goals', 'AI reasoning'],
#  ['ability', 'long term goals'],
#  ['AI researchers', 'neural  statistics']]

# %%
#function to get the entity relations 
#The predicates are obtained, these are usually verb words
def get_relation(sent):
  
   doc = nlp(sent)
  
   matcher = Matcher(nlp.vocab)
  
   pattern = [{'DEP':'ROOT'},
           {'DEP':'prep','OP':"?"},
           {'DEP':'agent','OP':"?"}, 
           {'POS':'ADJ','OP':"?"}]
  
   matcher.add("matching_1", [pattern])
  
   matcher = matcher(doc)
   h = len(matcher) - 1
  
   span = doc[matcher[h][1]:matcher[h][2]]
  
   return (span.text)

# %%
dummy_sentence = "Fred plays football"
print(get_relation(dummy_sentence))
dummy_sentence_1 = "I drove Joe home because he lives close to my apartment."
print(get_relation(dummy_sentence_1))
# Out:
# plays
# drove

# %%
z = list(candidate_sentences['sentence'])
type(z)
relations = []
indx = []
#create the relation for the entity pairs
for i in range(len(z)):
    try:
      relations.append(get_relation(z[i]))
      indx.append(i)
    except:
      continue

# %%
pd.Series(relations).value_counts()[:50]
# Out:
# [                50
# is               31
# are              12
# include           8
# argues            6
# developed         6
# S                 6
# argue             5
# was               4
# used for          3
# g                 3
# used              3
# considers         3
# known as          3
# became            3
# used in           3
# need              2
# has               2
# 48                2
# use               2
# introduced by     2
# agreed            2
# defines           2
# failed            2
# inspired by       2
# uses              2
# called            2
# revived by        2
# said              2
# devised           2
# designed          2
# began             2
# were              2
# sought            2
# refer to          2
# reported          2
# U                 2
# have              2
# be able           2
# viewed as         2
# is difficult      2
# included          2
# suggested         2
# appeared as       2
# started           2
# 17                2
# led               2
# began with        2
# R                 2
# make many         1
# dtype: int64

# %%
#For the source and target nodes and the edge relation we build the graph
source=[];
target=[];
for i in indx:
  source.append(entity_pairs[i][0])
  target.append(entity_pairs[i][1])
kg_df = pd.DataFrame({'source':source, 'target':target, 'edge':relations})
kg_df
# Out:
#                        source                       target              edge
# 0    Artificial  intelligence                       humans                is
# 1                        this        other computer inputs           include
# 2             AI applications  advanced web search engines  include advanced
# 3                                                                          g
# 4                                 such recommendation Siri              cars
# ..                        ...                          ...               ...
# 463                                                                      233
# 464                     These                 used AI 2008              were
# 465                                                                 editions
# 466                                             used  2021      textbooks in
# 467            Open  Explorer         2021 Wayback Machine          Archived
#
# [468 rows x 3 columns]

# %%
# create a directed-graph from a dataframe
import networkx as nx
G=nx.from_pandas_edgelist(kg_df, "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

# %%
plt.figure(figsize=(12,12))
pos = nx.spring_layout(G)
nx.draw(G, with_labels=True, node_color='red', edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
# Iterate over the entities,predicates and link them to DBpedia
for i in range(len(source)):
    
    entity1 = source[i] #the source entity is assigned
    
    entity2 = target[i] #the target entity is also assigned

    relationship = relations[i]
    # Query DBpedia for candidate entities
    sparql = SPARQLWrapper("http://dbpedia.org/sparql")
    query = f"""
        SELECT DISTINCT ?s WHERE {{
            # ?s rdfs:label "{entity1}"@en.
        }}
    """
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    if len(results['results']['bindings'])>0:
      print(entity1,'-----> ',results['results']['bindings'][0]['s']['value'])
   
    query = f"""
        SELECT DISTINCT ?s WHERE {{
            # ?s rdfs:label "{entity2}"@en.
        }}
    """
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    if len(results['results']['bindings'])>0:
      print(entity2,'-----> ',results['results']['bindings'][0]['s']['value'])
    

    query = f"""
        SELECT DISTINCT ?s WHERE {{
            # ?s rdfs:label "{relationship}"@en.
        }}
    """
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    if len(results['results']['bindings'])>0:
      print(relationship,'-----> ',results['results']['bindings'][0]['s']['value'])
      print("Relationship")
    
    
type(results)
# Out:
# is ----->  http://dbpedia.org/property/is
# Relationship
# this ----->  http://dbpedia.org/property/this
# AI applications ----->  http://dbpedia.org/resource/AI_applications
# g ----->  http://dbpedia.org/property/g
# Relationship
# cars ----->  http://dbpedia.org/property/cars
# Relationship
# g ----->  http://dbpedia.org/property/g
# Relationship
# , ----->  http://dbpedia.org/resource/,
# Relationship
# founded as ----->  http://dbpedia.org/property/foundedAs
# Relationship
# AI research ----->  http://dbpedia.org/resource/AI_research
# fields ----->  http://dbpedia.org/property/fields
# adapted ----->  http://dbpedia.org/property/adapted
# Relationship
# AI ----->  http://dbpedia.org/resource/AI
# it ----->  http://dbpedia.org/property/it
# founded on ----->  http://dbpedia.org/property/foundedOn
# Relationship
# U ----->  http://dbpedia.org/resource/U
# Relationship
# R ----->  http://dbpedia.org/resource/R
# Relationship
# characters ----->  http://dbpedia.org/property/characters
# 17 ----->  http://dbpedia.org/resource/17
# Relationship
# machine ----->  http://dbpedia.org/property/machine
# known as ----->  http://dbpedia.org/property/knownAs
# Relationship
# This ----->  http://dbpedia.org/resource/This
# 20 ----->  http://dbpedia.org/resource/Category:20
# Relationship
# world ----->  http://dbpedia.org/property/world
# Allen Newell ----->  http://dbpedia.org/resource/Allen_Newell
# included ----->  http://dbpedia.org/property/included
# Relationship
# Simon ----->  http://dbpedia.org/resource/Simon
# Relationship
# James Manyika ----->  http://dbpedia.org/resource/James_Manyika
# field ----->  http://dbpedia.org/property/field
# AI research ----->  http://dbpedia.org/resource/AI_research
# produced ----->  http://dbpedia.org/property/produced
# Relationship
# U ----->  http://dbpedia.org/resource/U
# S ----->  http://dbpedia.org/resource/S
# Relationship
# world ----->  http://dbpedia.org/property/world
# funded by ----->  http://dbpedia.org/property/fundedBy
# Relationship
# Marvin Minsky ----->  http://dbpedia.org/resource/Marvin_Minsky
# generation ----->  http://dbpedia.org/property/generation
# problem ----->  http://dbpedia.org/property/problem
# 32 ----->  http://dbpedia.org/resource/Category:32
# Relationship
# They ----->  http://dbpedia.org/resource/They
# failed ----->  http://dbpedia.org/property/failed
# Relationship
# Progress ----->  http://dbpedia.org/resource/Progress
# S ----->  http://dbpedia.org/resource/S
# Relationship
# cut ----->  http://dbpedia.org/property/cut
# Relationship
# called ----->  http://dbpedia.org/property/called
# Relationship
# 5 ----->  http://dbpedia.org/resource/5
# Relationship
# market ----->  http://dbpedia.org/property/market
# U ----->  http://dbpedia.org/resource/U
# S ----->  http://dbpedia.org/resource/S
# Relationship
# restore ----->  http://dbpedia.org/property/restore
# Relationship
# began ----->  http://dbpedia.org/property/began
# Relationship
# number ----->  http://dbpedia.org/property/number
# began ----->  http://dbpedia.org/property/began
# Relationship
# environment ----->  http://dbpedia.org/property/environment
# Interest ----->  http://dbpedia.org/resource/Category:Interest
# AI ----->  http://dbpedia.org/resource/AI
# restored ----->  http://dbpedia.org/property/restored
# Relationship
# used ----->  http://dbpedia.org/property/used
# Relationship
# started ----->  http://dbpedia.org/property/started
# Relationship
# He ----->  http://dbpedia.org/resource/He
# amount ----->  http://dbpedia.org/property/amount
# AI ----->  http://dbpedia.org/resource/AI
# broken ----->  http://dbpedia.org/property/broken
# Relationship
# traits ----->  http://dbpedia.org/property/traits
# developed ----->  http://dbpedia.org/property/developed
# Relationship
# developed ----->  http://dbpedia.org/property/developed
# Relationship
# They ----->  http://dbpedia.org/resource/They
# 48 ----->  http://dbpedia.org/resource/48
# Relationship
# is ----->  http://dbpedia.org/property/is
# Relationship
# developed ----->  http://dbpedia.org/property/developed
# Relationship
# facts ----->  http://dbpedia.org/property/facts
# is ----->  http://dbpedia.org/property/is
# Relationship
# 48 ----->  http://dbpedia.org/resource/48
# Relationship
# used in ----->  http://dbpedia.org/property/usedIn
# Relationship
# 61 ----->  http://dbpedia.org/resource/61
# Relationship
# is ----->  http://dbpedia.org/property/is
# Relationship
# input ----->  http://dbpedia.org/property/input
# inputs ----->  http://dbpedia.org/property/inputs
# is ----->  http://dbpedia.org/property/is
# Relationship
# agent ----->  http://dbpedia.org/ontology/Agent
# agent ----->  http://dbpedia.org/ontology/Agent
# is ----->  http://dbpedia.org/property/is
# Relationship
# 67 ----->  http://dbpedia.org/resource/67
# Relationship
# 70 ----->  http://dbpedia.org/resource/70
# Relationship
# Symbolic AI ----->  http://dbpedia.org/resource/Symbolic_AI
# This ----->  http://dbpedia.org/resource/This
# failed ----->  http://dbpedia.org/property/failed
# Relationship
# text ----->  http://dbpedia.org/property/text
# They ----->  http://dbpedia.org/resource/They
# 72 ----->  http://dbpedia.org/resource/72
# Relationship
# is ----->  http://dbpedia.org/property/is
# Relationship
# Applications ----->  http://dbpedia.org/resource/Applications
# Computer vision ----->  http://dbpedia.org/resource/Computer_vision
# is ----->  http://dbpedia.org/property/is
# Relationship
# is ----->  http://dbpedia.org/property/is
# Relationship
# 80 ----->  http://dbpedia.org/resource/80
# Relationship
# machine ----->  http://dbpedia.org/property/machine
# AGI ----->  http://dbpedia.org/resource/AGI
# AI ----->  http://dbpedia.org/resource/AI
# Reasoning ----->  http://dbpedia.org/resource/Category:Reasoning
# search ----->  http://dbpedia.org/property/search
# is ----->  http://dbpedia.org/property/is
# Relationship
# is ----->  http://dbpedia.org/property/is
# Relationship
# supply ----->  http://dbpedia.org/property/supply
# Relationship
# Heuristics ----->  http://dbpedia.org/resource/Category:Heuristics
# limit ----->  http://dbpedia.org/property/limit
# Relationship
# 90 ----->  http://dbpedia.org/resource/90
# Relationship
# top ----->  http://dbpedia.org/property/top
# begin ----->  http://dbpedia.org/property/begin
# Relationship
# uses ----->  http://dbpedia.org/property/uses
# Relationship
# 93 ----->  http://dbpedia.org/resource/93
# Relationship
# uses ----->  http://dbpedia.org/property/uses
# Relationship
# AI research ----->  http://dbpedia.org/resource/AI_research
# used in ----->  http://dbpedia.org/property/usedIn
# Relationship
# other ----->  http://dbpedia.org/ontology/other
# designed ----->  http://dbpedia.org/property/designed
# Relationship
# designed ----->  http://dbpedia.org/property/designed
# Relationship
# time ----->  http://dbpedia.org/property/time
# g ----->  http://dbpedia.org/property/g
# Relationship
# models ----->  http://dbpedia.org/property/models
# Relationship
# 108 ----->  http://dbpedia.org/resource/108
# Relationship
# is ----->  http://dbpedia.org/property/is
# Relationship
# developed ----->  http://dbpedia.org/property/developed
# Relationship
# tools ----->  http://dbpedia.org/property/tools
# 112 ----->  http://dbpedia.org/resource/112
# Relationship
# Controllers ----->  http://dbpedia.org/resource/Controllers
# classify ----->  http://dbpedia.org/property/classify
# Relationship
# examples ----->  http://dbpedia.org/property/examples
# observations ----->  http://dbpedia.org/property/observations
# known as ----->  http://dbpedia.org/property/knownAs
# Relationship
# is ----->  http://dbpedia.org/property/is
# Relationship
# observations ----->  http://dbpedia.org/property/observations
# known as ----->  http://dbpedia.org/property/knownAs
# Relationship
# observation ----->  http://dbpedia.org/property/observation
# 113 ----->  http://dbpedia.org/resource/113
# Relationship
# is ----->  http://dbpedia.org/property/is
# Relationship
# displaced ----->  http://dbpedia.org/property/displaced
# Relationship
# is ----->  http://dbpedia.org/property/is
# Relationship
# is ----->  http://dbpedia.org/property/is
# Relationship
# inspired by ----->  http://dbpedia.org/property/inspiredBy
# Relationship
# is ----->  http://dbpedia.org/property/is
# Relationship
# process ----->  http://dbpedia.org/property/process
# Relationship
# They ----->  http://dbpedia.org/resource/They
# network ----->  http://dbpedia.org/property/network
# is ----->  http://dbpedia.org/property/is
# Relationship
# 122 ----->  http://dbpedia.org/resource/122
# Relationship
# 123 ----->  http://dbpedia.org/resource/123
# Relationship
# This ----->  http://dbpedia.org/resource/This
# is ----->  http://dbpedia.org/property/is
# Relationship
# developed ----->  http://dbpedia.org/property/developed
# Relationship
# Hardware ----->  http://dbpedia.org/resource/Category:Hardware
# AI accelerators ----->  http://dbpedia.org/resource/Category:AI_accelerators
# includes ----->  http://dbpedia.org/property/includes
# Relationship
# AI ----->  http://dbpedia.org/resource/AI
# AI effect ----->  http://dbpedia.org/resource/AI_effect
# 137 ----->  http://dbpedia.org/resource/137
# Relationship
# AI applications ----->  http://dbpedia.org/resource/AI_applications
# AI ----->  http://dbpedia.org/resource/AI
# used in ----->  http://dbpedia.org/property/usedIn
# Relationship
# diagnosis ----->  http://dbpedia.org/property/diagnosis
# Relationship
# 1950s ----->  http://dbpedia.org/resource/1950s
# Deep Blue ----->  http://dbpedia.org/resource/Deep_Blue
# defeated ----->  http://dbpedia.org/property/defeated
# Relationship
# won ----->  http://dbpedia.org/property/won
# Relationship
# developed ----->  http://dbpedia.org/property/developed
# Relationship
# 150 ----->  http://dbpedia.org/resource/150
# Relationship
# tools ----->  http://dbpedia.org/property/tools
# used ----->  http://dbpedia.org/property/used
# Relationship
# benefits ----->  http://dbpedia.org/property/benefits
# developed at ----->  http://dbpedia.org/property/developedAt
# Relationship
# started ----->  http://dbpedia.org/property/started
# Relationship
# It ----->  http://dbpedia.org/resource/It
# It ----->  http://dbpedia.org/resource/It
# followed ----->  http://dbpedia.org/property/followed
# Relationship
# Companies ----->  http://dbpedia.org/resource/Companies
# is ----->  http://dbpedia.org/property/is
# Relationship
# magnitude ----->  http://dbpedia.org/property/magnitude
# included ----->  http://dbpedia.org/property/included
# Relationship
# IBM ----->  http://dbpedia.org/resource/Category:IBM
# it ----->  http://dbpedia.org/property/it
# 160 ----->  http://dbpedia.org/resource/160
# Relationship
# AI ----->  http://dbpedia.org/resource/AI
# terms ----->  http://dbpedia.org/property/terms
# test ----->  http://dbpedia.org/property/test
# people ----->  http://dbpedia.org/property/people
# McCarthy ----->  http://dbpedia.org/resource/McCarthy
# Marvin Minsky ----->  http://dbpedia.org/resource/Marvin_Minsky
# view ----->  http://dbpedia.org/property/view
# Relationship
# needed ----->  http://dbpedia.org/property/needed
# Relationship
# approach ----->  http://dbpedia.org/property/approach
# is ----->  http://dbpedia.org/property/is
# Relationship
# They ----->  http://dbpedia.org/resource/They
# proposed ----->  http://dbpedia.org/property/proposed
# Relationship
# 169 ----->  http://dbpedia.org/resource/169
# Relationship
# AI ----->  http://dbpedia.org/resource/AI
# is ----->  http://dbpedia.org/property/is
# Relationship
# it ----->  http://dbpedia.org/property/it
# Finding ----->  http://dbpedia.org/resource/Finding
# is ----->  http://dbpedia.org/property/is
# Relationship
# sub ----->  http://dbpedia.org/property/sub
# Relationship
# issue ----->  http://dbpedia.org/property/issue
# it ----->  http://dbpedia.org/property/it
# field ----->  http://dbpedia.org/property/field
# It ----->  http://dbpedia.org/resource/It
# is ----->  http://dbpedia.org/property/is
# Relationship
# red ----->  http://dbpedia.org/property/red
# view ----->  http://dbpedia.org/property/view
# is ----->  http://dbpedia.org/property/is
# Relationship
# relationship ----->  http://dbpedia.org/property/relationship
# inspired by ----->  http://dbpedia.org/property/inspiredBy
# Relationship
# counters ----->  http://dbpedia.org/property/counters
# Relationship
# discussion ----->  http://dbpedia.org/property/discussion
# Future ----->  http://dbpedia.org/resource/Category:Future
# is ----->  http://dbpedia.org/property/is
# Relationship
# Superintelligence ----->  http://dbpedia.org/resource/Superintelligence
# 178 ----->  http://dbpedia.org/resource/178
# Relationship
# increase ----->  http://dbpedia.org/property/increase
# Relationship
# events ----->  http://dbpedia.org/property/events
# is ----->  http://dbpedia.org/property/is
# Relationship
# estimate ----->  http://dbpedia.org/property/estimate
# Relationship
# S ----->  http://dbpedia.org/resource/S
# Relationship
# S ----->  http://dbpedia.org/resource/S
# Relationship
# states ----->  http://dbpedia.org/property/states
# Relationship
# 200 ----->  http://dbpedia.org/resource/200
# Relationship
# 201 ----->  http://dbpedia.org/resource/201
# Relationship
# Terrorists ----->  http://dbpedia.org/resource/Terrorists
# is ----->  http://dbpedia.org/property/is
# Relationship
# introduced by ----->  http://dbpedia.org/property/introducedBy
# Relationship
# introduced by ----->  http://dbpedia.org/property/introducedBy
# Relationship
# individual ----->  http://dbpedia.org/property/individual
# used ----->  http://dbpedia.org/property/used
# Relationship
# example ----->  http://dbpedia.org/property/example
# is ----->  http://dbpedia.org/property/is
# Relationship
# S ----->  http://dbpedia.org/resource/S
# Relationship
# defendant ----->  http://dbpedia.org/property/defendant
# courts ----->  http://dbpedia.org/property/courts
# Relationship
# claims ----->  http://dbpedia.org/property/claims
# Relationship
# bias ----->  http://dbpedia.org/property/bias
# credit rating ----->  http://dbpedia.org/property/creditRating
# 209 ----->  http://dbpedia.org/resource/209
# Relationship
# it ----->  http://dbpedia.org/property/it
# it ----->  http://dbpedia.org/property/it
# T ----->  http://dbpedia.org/resource/T
# Relationship
# Stephen Hawking ----->  http://dbpedia.org/resource/Stephen_Hawking
# It ----->  http://dbpedia.org/resource/It
# I ----->  http://dbpedia.org/resource/I
# 219 ----->  http://dbpedia.org/resource/219
# Relationship
# issues ----->  http://dbpedia.org/property/issues
# AI ----->  http://dbpedia.org/resource/AI
# Machines ----->  http://dbpedia.org/resource/Machines
# field ----->  http://dbpedia.org/property/field
# provides ----->  http://dbpedia.org/property/provides
# Relationship
# Machine ethics ----->  http://dbpedia.org/resource/Machine_ethics
# called ----->  http://dbpedia.org/property/called
# Relationship
# 225 ----->  http://dbpedia.org/resource/225
# Relationship
# is ----->  http://dbpedia.org/property/is
# Relationship
# is ----->  http://dbpedia.org/property/is
# Relationship
# Others ----->  http://dbpedia.org/resource/Others
# AI ----->  http://dbpedia.org/resource/AI
# published ----->  http://dbpedia.org/property/published
# Relationship
# 17 ----->  http://dbpedia.org/resource/17
# Relationship
# masters ----->  http://dbpedia.org/property/masters
# This ----->  http://dbpedia.org/resource/This
# Clarke ----->  http://dbpedia.org/resource/Clarke
# Relationship
# 230 ----->  http://dbpedia.org/resource/230
# Relationship
# Isaac Asimov ----->  http://dbpedia.org/resource/Category:Isaac_Asimov
# introduced ----->  http://dbpedia.org/property/introduced
# Relationship
# Transhumanism ----->  http://dbpedia.org/resource/Category:Transhumanism
# This ----->  http://dbpedia.org/resource/This
# U ----->  http://dbpedia.org/resource/U
# Relationship
# R ----->  http://dbpedia.org/resource/R
# Relationship
# films ----->  http://dbpedia.org/property/films
# Relationship
# I ----->  http://dbpedia.org/resource/I
# Relationship
# Artificial Intelligence ----->  http://dbpedia.org/resource/Artificial_Intelligence
# Do ----->  http://dbpedia.org/resource/Do
# Relationship
# Dick ----->  http://dbpedia.org/resource/Dick
# Relationship
# 233 ----->  http://dbpedia.org/resource/233
# Relationship
# These ----->  http://dbpedia.org/resource/These
# Archived ----->  http://dbpedia.org/resource/Archived
# Relationship
# dict
